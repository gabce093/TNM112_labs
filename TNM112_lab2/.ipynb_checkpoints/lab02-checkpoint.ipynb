# %% [markdown]
# # TNM112 -- Lab 2

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# A dataset can be generated with a randomly selected subset of training images, and with a specified fraction used to formulate a validation set. Here, we use the MNIST dataset of handwritten digits.

# %%
import data_generator

data = data_generator.DataGenerator()
data.generate(dataset='mnist', N_valid=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (54000, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)

# %% [markdown]
# ### Keras CNN
# A small CNN in Keras, trained with cross-entropy loss
#
# We use the functions in 'util.py' to evaluate the model and plot the training progress.

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util

keras.backend.clear_session()

model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))
model.add(layers.Conv2D(4, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Conv2D(8, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(data.K, activation='softmax'))
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=128, epochs=10, 
                validation_data=(data.x_valid, data.y_valid_oh), verbose=True)

util.evaluate(model, data, final=True)
util.plot_training(log)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 4)         40
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 4)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 8)         296
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 8)           0
#  g2D)
#
#  flatten (Flatten)           (None, 392)               0
#
#  dense (Dense)               (None, 10)                3930
#
# =================================================================
# Total params: 4266 (16.66 KB)
# Trainable params: 4266 (16.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 422/422 [==============================] - 4s 8ms/step - loss: 0.5958 - accuracy: 0.8271 - val_loss: 0.2061 - val_accuracy: 0.9360
# Epoch 2/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.1625 - accuracy: 0.9511 - val_loss: 0.1322 - val_accuracy: 0.9598
# Epoch 3/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.1163 - accuracy: 0.9649 - val_loss: 0.1050 - val_accuracy: 0.9678
# Epoch 4/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0980 - accuracy: 0.9699 - val_loss: 0.0880 - val_accuracy: 0.9730
# Epoch 5/10
# 422/422 [==============================] - 4s 8ms/step - loss: 0.0861 - accuracy: 0.9734 - val_loss: 0.0802 - val_accuracy: 0.9745
# Epoch 6/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0783 - accuracy: 0.9757 - val_loss: 0.0816 - val_accuracy: 0.9758
# Epoch 7/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0718 - accuracy: 0.9778 - val_loss: 0.0707 - val_accuracy: 0.9777
# Epoch 8/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0673 - accuracy: 0.9789 - val_loss: 0.0672 - val_accuracy: 0.9788
# Epoch 9/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0639 - accuracy: 0.9805 - val_loss: 0.0693 - val_accuracy: 0.9790
# Epoch 10/10
# 422/422 [==============================] - 3s 8ms/step - loss: 0.0616 - accuracy: 0.9811 - val_loss: 0.0708 - val_accuracy: 0.9785
# Model performance:
# 	Train loss:          0.0597
# 	Train accuracy:      98.17
# 	Test loss:           0.0652
# 	Test accuracy:       97.91

# %% [markdown]
# ### Our CNN
#
# #### Task 1
# Implement the following functions in cnn.py: 'activation', 'conv2d_layer', 'pool2d_layer', 'flatten_layer', 'dense_layer', and 'evaluate'. Additionally, compute the number of weights in the model, in the function 'setup_model'.
#
# For the 'activation' and 'dense_layer' functions you can use code that you wrote in Lab 1. For the 'evaluate' function you can use the code from Lab 1 for the accuracy. However, now we have trained with the cross-entropy loss, so you should evaluate this loss function through our CNN.
#
# When you have finished the implementation, you should be able to run this code and get the same result as with the Keras model above. However, our code is not optimized, nor parallelized, so it will be rather slow to process the full dataset. In order to facilitate comparisons when you implement the functions, please have a look in the next cell below.

# %%
import importlib
import cnn
importlib.reload(cnn)

# Get the weight matrices and biases of the trained Keras model
W, b, lname = util.get_weights(model)

# This is our implementation of a CNN, which we set to use the dataset we generated
cnn = cnn.CNN(data, verbose=True)

# Assign the weights and biases to the CNN and specify the activation function
cnn.setup_model(W, b, lname, activation='relu')

# Evaluate the model (accuracy on the training and test data)
cnn.evaluate()
# Out:
# Number of model weights:  4266
# Model performance:
# sample 0 of 54000
# sample 1000 of 54000
# sample 2000 of 54000
# sample 3000 of 54000
# sample 4000 of 54000
# sample 5000 of 54000
# sample 6000 of 54000
# sample 7000 of 54000
# sample 8000 of 54000
# sample 9000 of 54000
# sample 10000 of 54000
# sample 11000 of 54000
# sample 12000 of 54000
# sample 13000 of 54000
# sample 14000 of 54000
# sample 15000 of 54000
# sample 16000 of 54000
# sample 17000 of 54000
# sample 18000 of 54000
# sample 19000 of 54000
# sample 20000 of 54000
# sample 21000 of 54000
# sample 22000 of 54000
# sample 23000 of 54000
# sample 24000 of 54000
# sample 25000 of 54000
# sample 26000 of 54000
# sample 27000 of 54000
# sample 28000 of 54000
# sample 29000 of 54000
# sample 30000 of 54000
# sample 31000 of 54000
# sample 32000 of 54000
# sample 33000 of 54000
# sample 34000 of 54000
# sample 35000 of 54000
# sample 36000 of 54000
# sample 37000 of 54000
# sample 38000 of 54000
# sample 39000 of 54000
# sample 40000 of 54000
# sample 41000 of 54000
# sample 42000 of 54000
# sample 43000 of 54000
# sample 44000 of 54000
# sample 45000 of 54000
# sample 46000 of 54000
# sample 47000 of 54000
# sample 48000 of 54000
# sample 49000 of 54000
# sample 50000 of 54000
# sample 51000 of 54000
# sample 52000 of 54000
# sample 53000 of 54000
# 	Train loss:     0.0597
# 	Train accuracy: 98.17
# sample 0 of 10000
# sample 1000 of 10000
# sample 2000 of 10000
# sample 3000 of 10000
# sample 4000 of 10000
# sample 5000 of 10000
# sample 6000 of 10000
# sample 7000 of 10000
# sample 8000 of 10000
# sample 9000 of 10000
# 	Test loss:      0.0652
# 	Test accuracy:  97.91

# %% [markdown]
# ### Evaluation of our CNN layers
#
# #### Task 1
# As part of the implementation of the different layers in 'cnn.py', you can use the below code to compare the output of a randomly initialized Keras model and our CNN, for a single image. This is fast to compute, which will be convenient to check that your layers are correctly implemented.

# %%
import numpy as np
import cnn
importlib.reload(cnn)

# Secify a test layer for comparison: 'conv', 'pool', 'flatten', or 'dense'
test_layer = 'conv'

keras.backend.clear_session()

# Keras model and input layer
model = keras.Sequential()
model.add(layers.InputLayer(input_shape=data.x_train.shape[1:]))

# Test conv layer
#   - We apply normal initialization to the bias also,
#     otherwise it would be difficult to see the impact
#     of how you apply the bias (it is initialized to 0 by default)
if test_layer == 'conv':
    model.add(layers.Conv2D(4, kernel_size=(3, 3), 
                            activation='relu', padding='same',
                            bias_initializer='normal'))
    
    # You could also test to add a second convolutional layer, to check
    # that your network maps correctly from the output channels of the
    # previous layer, to the channels of this layer
    #model.add(layers.Conv2D(4, kernel_size=(3, 3), 
    #                        activation='relu', padding='same',
    #                        bias_initializer='normal'))

# Test pooling layer
elif test_layer == 'pool':
    model.add(layers.MaxPooling2D(pool_size=(2, 2)))

# Test flattening layer
elif test_layer == 'flatten':
    model.add(layers.Flatten())

# Test dense layer
#   - We need to first flatten the image input to apply a dense layer
#   - Make sure that your flatten layer works before testing the dense layer
elif test_layer == 'dense':
    model.add(layers.Flatten())
    model.add(layers.Dense(10, activation='softmax',
                           bias_initializer='normal'))

# Test data point (you could select any other image if you want)
x = data.x_train[0]

# Keras prediction. We need ta add an extra axis, 
# since the model can run over multiple datapoints. We 
# would need this in our model also if we use used the
# 'feedforward' function instead of the 'feedforward_sample'
y1 = model.predict(x[np.newaxis,:,:,:], verbose=False)

# Prediction with our network
W, b, lname = util.get_weights(model)  # Get the Keras model weights
cnn = cnn.CNN(data)
cnn.setup_model(W, b, lname, activation='relu') # Assign weights to our model
y2 = cnn.feedforward_sample(x) # Feedforward of one single sample

print('Evaluation of %s layer:'%test_layer)

# Check that the dimensionality is correct. The Keras
# model will have an extra first dimension due to the
# batch processing
print('\tShape of Keras output:  ', y1.shape)
print('\tShape of our output:    ', y2.shape)

# Print the absolute sum of output from the Keras
# model and our model. These should be the same if the
# implementation is correct
print('\tAbs sum of Keras model: ', np.sum(np.abs(y1)))
print('\tAbs sum of our model:   ', np.sum(np.abs(y2)))

# Print the absolute difference between the Keras
# model and our model. This should be very close
# to 0 if your implementation is correct. It could be
# a very minor difference due to numerical differences 
# (e.g., difference in precision used)
print('\tAbs difference:         ', np.sum(np.abs(y1-y2)))
# Out:
# Number of model weights:  40
# Evaluation of conv layer:
# 	Shape of Keras output:   (1, 28, 28, 4)
# 	Shape of our output:     (28, 28, 4)
# 	Abs sum of Keras model:  1084.2825
# 	Abs sum of our model:    1084.2825233149342
# 	Abs difference:          7.253000512719154e-05

# %% [markdown]
# ### MNIST with limited training data
# #### Task 2
# In this experiment, we select a random subset from MNIST, with only 128 images. This is a very minimal dataset, but it is interesting to see how overfitting can be prevented with regularization strategies.
#
# Your task is to expand the given network with different regularization strategies. You are free to choose which combination of strategies you want to use, for example augmentation layers, dropout, weight decay, batch normalization, etc. You can also expand the network with more layers, strided convolutions, or add skip-connections to facilitate optimization. Moreover, you can experiment with the number of training epochs and the batch size.
#
# Also, note that now we have specified the Keras network in a sligthly different way. We explicitly formulate the input and output to the different layers. One motiviation for this is that it is easier if we want to, e.g., add skip-connections (checkout the layers.Add() layer in Keras).
#
# During your development, you test the performance on the validation set (util.evaluate with the flag final=False). When you have found a good setup, run evaluation on the test set (final=True). Do this for at least 5 runs and report the average and the variance across models. Since the subset of 128 images is randomly selected and the optimization is stochastic, you will get slightly different values each time. Thus, averaging is important to get a robust indication of your model's performance. You can do this manually, or you can setup a for-loop to run a sequence of trainings, where you log the evaluation results for each model.
#
# For the final results, you should aim at having an average accuracy of at least 90% (which is quite good considering that we are only training on 128 images).

# %%
from tensorflow.keras import regularizers # Imported this for task 2 

# A block of convolutional layers followed by max pooling
def conv_block(x, N, channels, kernel_size, activation, padding='same'):
    for i in range(N):
        x = layers.Conv2D(channels, kernel_size=kernel_size, activation=activation, padding=padding)(x)
        #x = layers.Dropout(0.2)(x)
    return layers.MaxPooling2D(pool_size=(2, 2))(x)
    
epochs = 200
batch_size = 16

# For setting up averaging over multiple training runs
K = 5
acc = np.zeros((K,2))
for k in range(K):

    # MNIST with 128 randomly selected training images
    data = data_generator.DataGenerator()
    data.generate(dataset='mnist', N_train=128)
    
    keras.backend.clear_session()
    
    x       = layers.Input(shape=data.x_train.shape[1:])
    aug_rot = layers.RandomRotation(0.1)(x)
    aug_zoom= layers.RandomZoom(0.1)(aug_rot) 
    aug_tran= layers.RandomTranslation(0.1,0.2)(aug_zoom)
    conv1   = conv_block(aug_tran, N=2, channels=8, kernel_size=(3,3), activation='relu', padding='same')
    conv2   = conv_block(conv1, N=2, channels=16, kernel_size=(3,3), activation='relu', padding='same')
    conv3   = conv_block(conv2, N=2, channels=32, kernel_size=(3,3), activation='relu', padding='same')
    flat1   = layers.Flatten()(conv3)
    norm1   = layers.BatchNormalization()(flat1)
    drop1   = layers.Dropout(0.2)(norm1)
    dense1  = layers.Dense(512,kernel_regularizer=regularizers.L1(0.001), activation='relu')(drop1)
    y = layers.Dense(data.K, activation='softmax')(dense1)
    
    model = keras.models.Model(inputs=x, outputs=y)
    model.summary()
    
    opt = keras.optimizers.Adam()
    #model.add(Dropout(0.2, input_shape=(60,)))
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                    validation_data=(data.x_valid, data.y_valid_oh), validation_freq=10,  # We don't need to evaluate at each epoch
                    verbose=True)
    
    util.evaluate(model, data, final=True)
    util.plot_training(log)

# When you are finished with hyper-parameter tuning, you should evaluate
# your model on the test set, and average over 5 trainings. If you want
# to do this automatically, you can setup a foor loop and store each evaluation
    acc[k,:] = util.evaluate(model, data, final=True)
print("Accuracy: ", acc)
print("Mean Accuracy:", acc[:,1].mean())
print("Mean Varience:", np.var(acc[:,1]))

#Accuracy:  [[0.84226853 0.88669997]
# [0.67526418 0.91869998]
# [0.62206167 0.93409997]
# [0.58392018 0.94260001]
# [0.62354928 0.90570003]]
#Mean Accuracy: 0.9175599932670593
#Mean Varience: 0.00039897450737584
# Out:
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  random_rotation (RandomRot  (None, 28, 28, 1)         0
#  ation)
#
#  random_zoom (RandomZoom)    (None, 28, 28, 1)         0
#
#  random_translation (Random  (None, 28, 28, 1)         0
#  Translation)
#
#  conv2d (Conv2D)             (None, 28, 28, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 8)         584
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 8)         0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        2320
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 16)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 32)          9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 288)               0
#
#  batch_normalization (Batch  (None, 288)               1152
#  Normalization)
#
#  dropout (Dropout)           (None, 288)               0
#
#  dense (Dense)               (None, 512)               147968
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 172290 (673.01 KB)
# Trainable params: 171714 (670.76 KB)
# Non-trainable params: 576 (2.25 KB)
# _________________________________________________________________
# Epoch 1/200
# 8/8 [==============================] - 1s 10ms/step - loss: 8.5072 - accuracy: 0.1406
# Epoch 2/200
# 8/8 [==============================] - 0s 9ms/step - loss: 7.8770 - accuracy: 0.2344
# Epoch 3/200
# 8/8 [==============================] - 0s 9ms/step - loss: 7.3125 - accuracy: 0.3281
# Epoch 4/200
# 8/8 [==============================] - 0s 9ms/step - loss: 6.8613 - accuracy: 0.3516
# Epoch 5/200
# 8/8 [==============================] - 0s 9ms/step - loss: 6.3879 - accuracy: 0.4297
# Epoch 6/200
# 8/8 [==============================] - 0s 9ms/step - loss: 5.9639 - accuracy: 0.4922
# Epoch 7/200
# 8/8 [==============================] - 0s 9ms/step - loss: 5.7138 - accuracy: 0.4844
# Epoch 8/200
# 8/8 [==============================] - 0s 9ms/step - loss: 5.3805 - accuracy: 0.5781
# Epoch 9/200
# 8/8 [==============================] - 0s 9ms/step - loss: 5.1321 - accuracy: 0.5234
# Epoch 10/200
# 8/8 [==============================] - 1s 167ms/step - loss: 4.8866 - accuracy: 0.5703 - val_loss: 5.7015 - val_accuracy: 0.1325
# Epoch 11/200
# 8/8 [==============================] - 0s 9ms/step - loss: 4.6036 - accuracy: 0.6016
# Epoch 12/200
# 8/8 [==============================] - 0s 10ms/step - loss: 4.3693 - accuracy: 0.6406
# Epoch 13/200
# 8/8 [==============================] - 0s 9ms/step - loss: 4.2554 - accuracy: 0.6562
# Epoch 14/200
# 8/8 [==============================] - 0s 11ms/step - loss: 4.0526 - accuracy: 0.7344
# Epoch 15/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.9124 - accuracy: 0.6719
# Epoch 16/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.8547 - accuracy: 0.6328
# Epoch 17/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.6039 - accuracy: 0.7188
# Epoch 18/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.6354 - accuracy: 0.6953
# Epoch 19/200
# 8/8 [==============================] - 0s 10ms/step - loss: 3.6118 - accuracy: 0.6797
# Epoch 20/200
# 8/8 [==============================] - 1s 153ms/step - loss: 3.2520 - accuracy: 0.7734 - val_loss: 4.5139 - val_accuracy: 0.2787
# Epoch 21/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.2314 - accuracy: 0.7656
# Epoch 22/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.1365 - accuracy: 0.7344
# Epoch 23/200
# 8/8 [==============================] - 0s 9ms/step - loss: 3.0388 - accuracy: 0.7500
# Epoch 24/200
# 8/8 [==============================] - 0s 9ms/step - loss: 2.7854 - accuracy: 0.8281
# Epoch 25/200
# 8/8 [==============================] - 0s 9ms/step - loss: 2.8709 - accuracy: 0.7812
# Epoch 26/200
# 8/8 [==============================] - 0s 9ms/step - loss: 2
200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6483 - accuracy: 0.9062
# Epoch 182/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6160 - accuracy: 0.9297
# Epoch 183/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5686 - accuracy: 0.9688
# Epoch 184/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5815 - accuracy: 0.9453
# Epoch 185/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5371 - accuracy: 0.9688
# Epoch 186/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5685 - accuracy: 0.9297
# Epoch 187/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5707 - accuracy: 0.9688
# Epoch 188/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6096 - accuracy: 0.9375
# Epoch 189/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5075 - accuracy: 0.9609
# Epoch 190/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.5696 - accuracy: 0.9297 - val_loss: 0.8228 - val_accuracy: 0.8787
# Epoch 191/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5934 - accuracy: 0.9453
# Epoch 192/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5785 - accuracy: 0.9375
# Epoch 193/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6461 - accuracy: 0.9453
# Epoch 194/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5519 - accuracy: 0.9531
# Epoch 195/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5581 - accuracy: 0.9609
# Epoch 196/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6282 - accuracy: 0.9375
# Epoch 197/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5860 - accuracy: 0.9609
# Epoch 198/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5350 - accuracy: 0.9688
# Epoch 199/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5394 - accuracy: 0.9531
# Epoch 200/200
# 8/8 [==============================] - 1s 149ms/step - loss: 0.5886 - accuracy: 0.9062 - val_loss: 0.8869 - val_accuracy: 0.8765
# Model performance:
# 	Train loss:          0.5158
# 	Train accuracy:      97.66
# 	Test loss:           0.8423
# 	Test accuracy:       88.67
# Model performance:
# 	Train loss:          0.5158
# 	Train accuracy:      97.66
# 	Test loss:           0.8423
# 	Test accuracy:       88.67
# Data specification:
# 	Dataset type:           mnist
# 	Number of classes:      10
# 	Number of channels:     1
# 	Training data shape:    (128, 28, 28, 1)
# 	Validation data shape:  (6000, 28, 28, 1)
# 	Test data shape:        (10000, 28, 28, 1)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  random_rotation (RandomRot  (None, 28, 28, 1)         0
#  ation)
#
#  random_zoom (RandomZoom)    (None, 28, 28, 1)         0
#
#  random_translation (Random  (None, 28, 28, 1)         0
#  Translation)
#
#  conv2d (Conv2D)             (None, 28, 28, 8)         80
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 8)         584
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 8)         0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 16)        1168
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        2320
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 16)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 32)          4640
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 32)          9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 288)               0
#
#  batch_normalization (Batch  (None, 288)               1152
#  Normalization)
#
#  dropout (Dropout)           (None, 288)               0
#
#  dense (Dense)               (None, 512)               147968
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 172290 (673.01 KB)
# Trainable params: 171714 (670.76 KB)
# Non-trainable params: 576 (2.25 KB)
# _________________________________________________________________
# Epoch 1/200
# 8/8 [==============================] - 1s 9ms/step - loss: 8.4491 - accuracy: 0.1719
# Epoch 2/200
# 8/8 [==============================] - 0s 9ms/step - loss: 7.7612 - accuracy: 0.3672
# Epoch 3/200
# 8/8 [==============================] - 0s 9ms/step - loss: 7.1987 - accuracy: 0.3438
# Epoch 4/200
# 8/8 [==============================] - 0s 9ms/step - loss: 6.6678 - accuracy: 0.3516
# Epoch 5/200
# 8/8 [==============================] - 0s 9ms/step - loss: 6.2390 - accuracy: 0.3750
# Epoch 6/200
# 8/8 [==============================] - 0s 11ms/step - loss: 5.7212 - accuracy: 0.4297
# Epoch 7/200
# 8/8 [==============================] - 0s 9ms/step - loss: 5.2976 - accuracy: 0.5156
# Epoch 8/200
# 8/8 [==============================] - 0s 9ms/step - loss: 4.
200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9504 - accuracy: 0.9141
# Epoch 67/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9370 - accuracy: 0.9297
# Epoch 68/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8830 - accuracy: 0.9609
# Epoch 69/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9084 - accuracy: 0.9297
# Epoch 70/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.8518 - accuracy: 0.9688 - val_loss: 1.1947 - val_accuracy: 0.8237
# Epoch 71/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8960 - accuracy: 0.9453
# Epoch 72/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8905 - accuracy: 0.9531
# Epoch 73/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9139 - accuracy: 0.9141
# Epoch 74/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8475 - accuracy: 0.9297
# Epoch 75/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7855 - accuracy: 0.9688
# Epoch 76/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9284 - accuracy: 0.8828
# Epoch 77/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8899 - accuracy: 0.9062
# Epoch 78/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.9110 - accuracy: 0.9141
# Epoch 79/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8377 - accuracy: 0.9453
# Epoch 80/200
# 8/8 [==============================] - 1s 159ms/step - loss: 0.7943 - accuracy: 0.9609 - val_loss: 1.1967 - val_accuracy: 0.8223
# Epoch 81/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8884 - accuracy: 0.9141
# Epoch 82/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7493 - accuracy: 0.9609
# Epoch 83/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.8506 - accuracy: 0.9141
# Epoch 84/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7904 - accuracy: 0.9219
# Epoch 85/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8711 - accuracy: 0.9297
# Epoch 86/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8183 - accuracy: 0.9297
# Epoch 87/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7989 - accuracy: 0.9375
# Epoch 88/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8275 - accuracy: 0.9297
# Epoch 89/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7857 - accuracy: 0.9531
# Epoch 90/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.7595 - accuracy: 0.9297 - val_loss: 0.9832 - val_accuracy: 0.8820
# Epoch 91/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8322 - accuracy: 0.8984
# Epoch 92/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8011 - accuracy: 0.9219
# Epoch 93/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7440 - accuracy: 0.9531
# Epoch 94/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7532 - accuracy: 0.9453
# Epoch 95/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8024 - accuracy: 0.9375
# Epoch 96/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8054 - accuracy: 0.9297
# Epoch 97/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.8532 - accuracy: 0.9141
# Epoch 98/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7318 - accuracy: 0.9766
# Epoch 99/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7667 - accuracy: 0.9375
# Epoch 100/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.7539 - accuracy: 0.9609 - val_loss: 1.1602 - val_accuracy: 0.8312
# Epoch 101/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7841 - accuracy: 0.9453
# Epoch 102/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7323 - accuracy: 0.9609
# Epoch 103/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7657 - accuracy: 0.9375
# Epoch 104/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7978 - accuracy: 0.9219
# Epoch 105/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7897 - accuracy: 0.9219
# Epoch 106/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7539 - accuracy: 0.9453
# Epoch 107/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7496 - accuracy: 0.9531
# Epoch 108/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7046 - accuracy: 0.9766
# Epoch 109/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.7282 - accuracy: 0.9297
# Epoch 110/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.6882 - accuracy: 0.9609 - val_loss: 1.2537 - val_accuracy: 0.8112
# Epoch 111/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6887 - accuracy: 0.9375
# Epoch 112/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6347 - accuracy: 0.9688
# Epoch 113/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6598 - accuracy: 0.9688
# Epoch 114/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6186 - accuracy: 0.9609
# Epoch 115/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6437 - accuracy: 0.9609
# Epoch 116/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6151 - accuracy: 0.9688
# Epoch 117/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6723 - accuracy: 0.9453
# Epoch 118/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6463 - accuracy: 0.9453
# Epoch 119/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6296 - accuracy: 0.9609
# Epoch 120/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.6778 - accuracy: 0.9453 - val_loss: 0.8765 - val_accuracy: 0.8948
# Epoch 121/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6678 - accuracy: 0.9375
# Epoch 122/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6909 - accuracy: 0.9531
# Epoch 123/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6364 - accuracy: 0.9531
# Epoch 124/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6582 - accuracy: 0.9531
# Epoch 125/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6951 - accuracy: 0.9453
# Epoch 126/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.9688
# Epoch 127/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6196 - accuracy: 0.9609
# Epoch 128/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5889 - accuracy: 0.9844
# Epoch 129/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5913 - accuracy: 0.9766
# Epoch 130/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.5293 - accuracy: 1.0000 - val_loss: 0.7964 - val_accuracy: 0.8927
# Epoch 131/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5698 - accuracy: 0.9688
# Epoch 132/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5656 - accuracy: 0.9531
# Epoch 133/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5834 - accuracy: 0.9531
# Epoch 134/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5712 - accuracy: 0.9609
# Epoch 135/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6087 - accuracy: 0.9688
# Epoch 136/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6060 - accuracy: 0.9609
# Epoch 137/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5714 - accuracy: 0.9766
# Epoch 138/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5793 - accuracy: 0.9609
# Epoch 139/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5874 - accuracy: 0.9609
# Epoch 140/200
# 8/8 [==============================] - 1s 142ms/step - loss: 0.5512 - accuracy: 0.9844 - val_loss: 1.0844 - val_accuracy: 0.8075
# Epoch 141/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6100 - accuracy: 0.9453
# Epoch 142/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6198 - accuracy: 0.9453
# Epoch 143/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6291 - accuracy: 0.9375
# Epoch 144/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5789 - accuracy: 0.9688
# Epoch 145/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6501 - accuracy: 0.9453
# Epoch 146/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6011 - accuracy: 0.9531
# Epoch 147/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5682 - accuracy: 0.9844
# Epoch 148/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5592 - accuracy: 0.9766
# Epoch 149/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5224 - accuracy: 0.9922
# Epoch 150/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.4909 - accuracy: 0.9844 - val_loss: 0.7673 - val_accuracy: 0.8917
# Epoch 151/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5043 - accuracy: 0.9688
# Epoch 152/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4830 - accuracy: 0.9688
# Epoch 153/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5025 - accuracy: 0.9609
# Epoch 154/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6058 - accuracy: 0.9375
# Epoch 155/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5817 - accuracy: 0.9688
# Epoch 156/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5545 - accuracy: 0.9688
# Epoch 157/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5782 - accuracy: 0.9453
# Epoch 158/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5903 - accuracy: 0.9688
# Epoch 159/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5564 - accuracy: 0.9766
# Epoch 160/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.5618 - accuracy: 0.9609 - val_loss: 0.8192 - val_accuracy: 0.8922
# Epoch 161/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5454 - accuracy: 0.9688
# Epoch 162/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5252 - accuracy: 0.9766
# Epoch 163/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5735 - accuracy: 0.9375
# Epoch 164/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4899 - accuracy: 0.9922
# Epoch 165/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5085 - accuracy: 0.9688
# Epoch 166/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5164 - accuracy: 0.9766
# Epoch 167/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5080 - accuracy: 0.9766
# Epoch 168/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5235 - accuracy: 0.9609
# Epoch 169/200
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4888 - accuracy: 0.9688
# Epoch 170/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.5139 - accuracy: 0.9609 - val_loss: 0.7652 - val_accuracy: 0.8882
# Epoch 171/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4750 - accuracy: 0.9844
# Epoch 172/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4615 - accuracy: 0.9766
# Epoch 173/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4613 - accuracy: 0.9688
# Epoch 174/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4878 - accuracy: 0.9844
# Epoch 175/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5101 - accuracy: 0.9609
# Epoch 176/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5529 - accuracy: 0.9609
# Epoch 177/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5652 - accuracy: 0.9609
# Epoch 178/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5495 - accuracy: 0.9609
# Epoch 179/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5882 - accuracy: 0.9531
# Epoch 180/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.5386 - accuracy: 0.9766 - val_loss: 0.8684 - val_accuracy: 0.8800
# Epoch 181/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5419 - accuracy: 0.9688
# Epoch 182/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5040 - accuracy: 0.9688
# Epoch 183/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5311 - accuracy: 0.9531
# Epoch 184/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5099 - accuracy: 0.9531
# Epoch 185/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5173 - accuracy: 0.9688
# Epoch 186/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5365 - accuracy: 0.9609
# Epoch 187/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4716 - accuracy: 0.9922
# Epoch 188/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4960 - accuracy: 0.9688
# Epoch 189/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4785 - accuracy: 0.9766
# Epoch 190/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.4928 - accuracy: 0.9609 - val_loss: 0.7510 - val_accuracy: 0.8973
# Epoch 191/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5002 - accuracy: 0.9297
# Epoch 192/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4522 - accuracy: 0.9688
# Epoch 193/200
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4541 - accuracy: 0.9766
# Epoch 194/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4627 - accuracy: 0.9688
# Epoch 195/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4171 - accuracy: 0.9844
# Epoch 196/200
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4476 - accuracy: 0.9766
# Epoch 197/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3729 - accuracy: 1.0000
# Epoch 198/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4148 - accuracy: 0.9766
# Epoch 199/200
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3934 - accuracy: 0.9766
# Epoch 200/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.3811 - accuracy: 0.9922 - val_loss: 0.5875 - val_accuracy: 0.9123
# Model performance:
# 	Train loss:          0.3125
# 	Train accuracy:      100.00
# 	Test loss:           0.6235
# 	Test accuracy:       90.57
# Model performance:
# 	Train loss:          0.3125
# 	Train accuracy:      100.00
# 	Test loss:           0.6235
# 	Test accuracy:       90.57
# Accuracy:  [[0.84226853 0.88669997]
#  [0.67526418 0.91869998]
#  [0.62206167 0.93409997]
#  [0.58392018 0.94260001]
#  [0.62354928 0.90570003]]
# Mean Accuracy: 0.9175599932670593
# Mean Varience: 0.00039897450737584

# %% [markdown]
# ### Tumor classification in digital pathology
# #### Task 3
# In this task, we will look at a more difficult task, using the PatchCamelyon dataset. This contains tissue samples from breast lymph nodes, which could either be healthy or contain tumor tissue, i.e. this is a binary classification problem. For this reason, it is valuable to also evaluate the AU-ROC, which can be passed to Keras as an evaluation metric, 'AUC'.
#
# You are provided with the training and validation set. These have been cropped to 32x32 pixels, to make it a bit less resource demanding to train. The test set is also provided, but without labels.
#
# Your task is to setup a Keras model to achieve the best possible performance on the validation set. You are free to choose how to do this, e.g., by means of regularization and network specifications. You can, for example, use your results from Task 2 as a starting point, but you should also think around how this problem differs from the MNIST classification. For example, in this case the orientation of images has no meaning, so you can randomly flip images both horizontally and vertically. You can also, e.g., explore augmentation by means of changing the image contrast and brightness.
#
# When you are finished with your development, you should run the 'util.pred_test' (at the bottom of the cell), to produce a CSV file with predictions of the test set. The exported CSV file should be uploaded to the Kaggle challenge, as described in the lab information. You need to train the model and export a CSV file 5 times, in order to have a good estimate for your model's performance. There are no requirements on how well your model should perform, as long as it is well above random guessing (50% accuracy).

# %%
from tensorflow import keras
from tensorflow.keras import layers
import util
import data_generator

def conv_block(x, N, channels, kernel_size, activation, padding='same'):
    for i in range(N):
        x = layers.Conv2D(channels, kernel_size=kernel_size, activation=activation, padding=padding)(x)
        #x = layers.Dropout(0.2)(x)
    return layers.MaxPooling2D(pool_size=(2, 2))(x)
    

epochs = 10
batch_size = 128

# Load the PatchCamyleon dataset
# In this dataset, we don't have labels for the test set.
# Do your development by monitoring the validation performance,
# and when you are finished you will run predictions on the test
# set and produce a CSV file that you can upload to Kaggle.
data = data_generator.DataGenerator()
data.generate(dataset='patchcam')
data.plot()

keras.backend.clear_session()

# TODO: Build your network here
x       = layers.Input(shape=data.x_train.shape[1:])
conv1   = conv_block(x, N=2, channels=8, kernel_size=(3,3), activation='relu', padding='same')
conv2   = conv_block(conv1, N=2, channels=16, kernel_size=(3,3), activation='relu', padding='same')
flat1   = layers.Flatten()(conv2)
y       = layers.Dense(data.K, activation='softmax')(flat1)

model = keras.models.Model(inputs=x, outputs=y)
model.summary()

opt = keras.optimizers.Adam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy','AUC'])
log = model.fit(data.x_train, data.y_train_oh, batch_size=batch_size, epochs=epochs, 
                validation_data=(data.x_valid, data.y_valid_oh), validation_freq=1,
                verbose=True)

util.evaluate(model, data)
util.plot_training(log)

# TODO: When you have finished your model development, you should 
# run inference on the test set and export a CSV file that can be 
# uploaded to Kaggle
#util.pred_test(model, data, name='your_submission.csv')
# Out:
# Data specification:
# 	Dataset type:           patchcam
# 	Number of classes:      2
# 	Number of channels:     3
# 	Training data shape:    (100000, 32, 32, 3)
# 	Validation data shape:  (32768, 32, 32, 3)
# 	Test data shape:        (32768, 32, 32, 3)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  flatten (Flatten)           (None, 3072)              0
#
#  dense (Dense)               (None, 2)                 6146
#
# =================================================================
# Total params: 6146 (24.01 KB)
# Trainable params: 6146 (24.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 782/782 [==============================] - 10s 12ms/step - loss: 0.6845 - accuracy: 0.5940 - auc: 0.6232 - val_loss: 0.6408 - val_accuracy: 0.6457 - val_auc: 0.6927
# Epoch 2/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6433 - accuracy: 0.6351 - auc: 0.6828 - val_loss: 0.6123 - val_accuracy: 0.6518 - val_auc: 0.7231
# Epoch 3/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6308 - accuracy: 0.6535 - auc: 0.7053 - val_loss: 0.6169 - val_accuracy: 0.6834 - val_auc: 0.7386
# Epoch 4/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6205 - accuracy: 0.6656 - auc: 0.7218 - val_loss: 0.6084 - val_accuracy: 0.6902 - val_auc: 0.7484
# Epoch 5/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6114 - accuracy: 0.6770 - auc: 0.7353 - val_loss: 0.5945 - val_accuracy: 0.6980 - val_auc: 0.7582
# Epoch 6/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6092 - accuracy: 0.6802 - auc: 0.7393 - val_loss: 0.5899 - val_accuracy: 0.6950 - val_auc: 0.7633
# Epoch 7/10
# 782/782 [==============================] - 5s 6ms/step - loss: 0.6060 - accuracy: 0.6873 - auc: 0.7451 - val_loss: 0.6216 - val_accuracy: 0.6815 - val_auc: 0.7329
# Epoch 8/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6065 - accuracy: 0.6840 - auc: 0.7452 - val_loss: 0.5882 - val_accuracy: 0.6996 - val_auc: 0.7625
# Epoch 9/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6042 - accuracy: 0.6893 - auc: 0.7491 - val_loss: 0.5865 - val_accuracy: 0.7034 - val_auc: 0.7668
# Epoch 10/10
# 782/782 [==============================] - 2s 2ms/step - loss: 0.6028 - accuracy: 0.6911 - auc: 0.7511 - val_loss: 0.6042 - val_accuracy: 0.6837 - val_auc: 0.7439
# Model performance:
# 	Train loss:          0.5990
# 	Train accuracy:      68.07
# 	Train AUC:           0.75
# 	Validation loss:     0.6042
# 	Validation accuracy: 68.37
# 	Validation AUC:     0.74
